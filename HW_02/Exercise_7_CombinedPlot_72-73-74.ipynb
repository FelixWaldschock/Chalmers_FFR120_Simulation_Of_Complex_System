# %% [markdown]
# FFR 120
# Felix Waldschock
#
# HW 2
# Plot of 7.2, 7.3, 7.4

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use(['science','grid'])

# %%
# load all data
folder = "Simulated_Data/"

## load all trajectories
trajectory_72 = np.loadtxt(folder+"trajectories_72.npy")
trajectory_73 = np.loadtxt(folder+"trajectories_73.npy")
trajectory_74_05 = np.loadtxt(folder+"trajectories_74_0-5.npy")
#trajectory_72_1 = np.loadtxt(folder+"trajectories_72_1.npy")

trajectories_ = [trajectory_72, trajectory_73, trajectory_74_05]

## load sigmas
sigmas_72 = np.loadtxt(folder+"sigmas_72.npy")
sigmas_73 = np.loadtxt(folder+"sigmas_73.npy")
sigmas_74_05 = np.loadtxt(folder+"sigmas_74_0-5.npy")
#trajectory_72_1 = np.loadtxt(folder+"trajectories_72_1.npy")

# %%
# create subplot 2x4
plt.subplots(2,4, figsize=(10,4))
bins = 100
# plot all trajectories as histograms
for j in range(len(trajectories_)):
    trajectories = trajectories_[j]
# plot all four time intervalls
    for i in range(4):
        plt.subplot(2,4,i+1)
        plt.hist(trajectories[:, 0], bins=bins, density=True, label='T = 10')
        plt.hist(trajectories[:, 1], bins=bins, density=True, label='T = 100')
        plt.hist(trajectories[:, 2], bins=bins, density=True, label='T = 1000')
        plt.hist(trajectories[:, 3], bins=bins, density=True, label='T = 10000')
